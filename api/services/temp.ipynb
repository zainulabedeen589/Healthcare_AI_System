# %%
import joblib
from pathlib import Path


# BASE_DIR = Path(__file__).resolve().parents[2]
BASE_DIR = "/Users/Apple/ZAINUL_AI/DS/Healt_Care/"
MODELS_DIR = BASE_DIR +  "/models"

MODELS_DIR
# Out:
# '/Users/Apple/ZAINUL_AI/DS/Healt_Care//models'
